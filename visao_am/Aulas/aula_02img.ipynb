# %%
path = 'E:/visao_am/imagens_visao_am/'

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
from pylab import *

# %%
im_1 = array(Image.open(path + 'marina-bay-sands.jpg'))

# %%
im_1
# Out:
# array([[[189, 207, 243],
#         [189, 207, 243],
#         [189, 207, 243],
#         ...,
#         [150, 191, 245],
#         [149, 190, 246],
#         [149, 190, 246]],
#
#        [[189, 207, 243],
#         [189, 207, 243],
#         [189, 207, 243],
#         ...,
#         [150, 191, 245],
#         [150, 191, 247],
#         [149, 190, 246]],
#
#        [[189, 207, 243],
#         [189, 207, 243],
#         [189, 207, 243],
#         ...,
#         [151, 191, 243],
#         [150, 191, 245],
#         [150, 191, 245]],
#
#        ...,
#
#        [[ 97, 115, 129],
#         [ 95, 114, 128],
#         [ 79,  98, 113],
#         ...,
#         [122, 153, 174],
#         [122, 153, 174],
#         [113, 144, 164]],
#
#        [[ 85, 103, 115],
#         [ 85, 105, 116],
#         [ 74,  93, 107],
#         ...,
#         [124, 152, 173],
#         [126, 154, 175],
#         [123, 152, 170]],
#
#        [[ 78,  96, 108],
#         [ 81, 101, 112],
#         [ 75,  94, 108],
# ...

# %%
imshow(im_1)

# %%
im_1.shape
# Out:
# (2592, 3888, 3)

# %%
def plot_im2(im1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1, 2, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 2, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
plot_im2(im_1, 'Imagem 1', im_1, 'Imagem 2', (12, 10))

# %%
def plot_im3(im1, tit1, im2, tit2, im3, tit3, tam):
    figure(figsize = tam)
    plt.subplot(1, 3, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    
    plt.subplot(1, 3, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])

    plt.subplot(1, 3, 3), plt.imshow(im3), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
plot_im3(im_1, 'Imagem 1', im_1, 'Imagem 2', im_1, 'Image 3', (12, 10))

# %%
im_p = Image.fromarray(np.uint8(im_1))
im_p = ImageOps.equalize(im_p)

# %%
plot_im2(im_1, 'Original', im_p, 'Processada', (15, 12))

# %%
im_1.ravel()
# Out:
# array([189, 207, 243, ..., 129, 156, 175], dtype=uint8)

# %%
im_1.ravel().shape
# Out:
# (30233088,)

# %%
im_1.shape
# Out:
# (2592, 3888, 3)

# %%
plt.hist(im_1.ravel())
# Out:
# (array([1507561., 1282997., 1701294., 2087936., 2336127., 2708112.,
#         3055581., 3825816., 6863880., 4863784.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
type(im_1), type(im_p)
# Out:
# (numpy.ndarray, PIL.Image.Image)

# %%
im_p = array(im_p)

# %%
im_1_i = np.invert(im_1)

# %%
np.save('marina-bay-sands.jpg', im_1_i)

# %%
plot_im3(im_1, 'Original', im_p, 'Processada', im_1_i, 'Invertida',(15, 12))

# %%
plt.hist(im_p.ravel())
# Out:
# (array([3069472., 2942978., 3087883., 2998221., 3076335., 3029724.,
#         3277558., 3201239., 2945304., 2604374.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
canalRed = im_1[:,:,0]
canalGreen = im_1[:,:,1]
canalBlue = im_1[:,:,2]

# %%
plot_im3(canalRed, 'vermelho', canalGreen, 'canalGreen', canalBlue, 'canalBlue',(15, 12))

# %%
im_1.shape
# Out:
# (2592, 3888, 3)

# %%
im1_parte1 = im_1[1000:1200, 1000:1200]

# %%
plt.imshow(im1_parte1)

# %%
im1_parte2 = im_1[1000:9000, 1200:8300]

# %%
plt.imshow(im1_parte2)

# %%
import cv2

# %%
im_cv1 = cv2.imread(path + 'marina-bay-sands.jpg')

# %%
plt.imshow(im_cv1)

# %%
im_cv1_c = cv2.cvtColor(im_cv1, cv2.COLOR_BGR2RGB)

# %%
cv2_imwrite('marina-bay-sands.jpg', variavel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 cv2_imwrite('marina-bay-sands.jpg', variavel)
#
# NameError: name 'cv2_imwrite' is not defined
