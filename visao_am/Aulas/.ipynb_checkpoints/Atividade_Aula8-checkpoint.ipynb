# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
num_classes = 2

# %%
modelo_base = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
modelo_base.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
# ...

# %%
for layer in modelo_base.layers:   # Congela todas as camadas do modelo base para que seus pesos não sejam atualizados durante o treinamento
    layer.trainable = False

# %%
# Cria um modelo sequencial adicionando o modelo base pré-treinado, uma camada de pooling global,
# uma camada densa com 1024 neurônios e ReLU, e uma camada de saída com softmax para classificação
modelo = tf.keras.Sequential(
    [modelo_base,
    GlobalAveragePooling2D(),
    Dense(1024, activation='relu'),
    Dense(num_classes, activation = 'softmax')
    ])

# %%
# Compila o modelo configurando o otimizador Adam com taxa de aprendizado de 0.001,
# a função de perda categorical_crossentropy para classificação categórica,
# e a métrica de acurácia para avaliar a performance do modelo
modelo.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
path = 'C:/Users/sabri/Desktop/Visao-Computacional/visao_am/dc_small/'

# %%
def criar_dataframe(caminho):
    arquivos = []
    rotulos = []

    for arquivo in os.listdir(caminho):
        if arquivo.startswith('cat'):
            rotulos.append('cat')
        elif arquivo.startswith('dog'):
            rotulos.append('dog')
        arquivos.append(arquivo)
    return pd.DataFrame({'arquivo': arquivos, 'rotulo': rotulos})

# %%
df_dados = criar_dataframe(os.path.join(path, 'train'))

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   arquivo  2000 non-null   object
#  1   rotulo   2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
df_dados.tail(10)
# Out:
#           arquivo rotulo
# 1990  dog.990.jpg    dog
# 1991  dog.991.jpg    dog
# 1992  dog.992.jpg    dog
# 1993  dog.993.jpg    dog
# 1994  dog.994.jpg    dog
# 1995  dog.995.jpg    dog
# 1996  dog.996.jpg    dog
# 1997  dog.997.jpg    dog
# 1998  dog.998.jpg    dog
# 1999  dog.999.jpg    dog

# %%
df_dados.head
# Out:
# <bound method NDFrame.head of           arquivo rotulo
# 0       cat.0.jpg    cat
# 1       cat.1.jpg    cat
# 2      cat.10.jpg    cat
# 3     cat.100.jpg    cat
# 4     cat.101.jpg    cat
# ...           ...    ...
# 1995  dog.995.jpg    dog
# 1996  dog.996.jpg    dog
# 1997  dog.997.jpg    dog
# 1998  dog.998.jpg    dog
# 1999  dog.999.jpg    dog
#
# [2000 rows x 2 columns]>

# %%
train_df, validation_df = train_test_split(df_dados, test_size=0.2, stratify=df_dados['rotulo'])

# %%
test_df = criar_dataframe(os.path.join(path, 'test1'))

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
validation_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df,
    directory=os.path.join(path, 'train'),
    x_col='arquivo',
    y_col='rotulo',
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 1600 validated image filenames belonging to 2 classes.

# %%
validation_generator = validation_datagen.flow_from_dataframe(
    validation_df,
    directory=os.path.join(path, 'train'),
    x_col  = 'arquivo',
    y_col = 'rotulo',
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 400 validated image filenames belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_dataframe(
    test_df,
    directory=os.path.join(path, 'test1'),
    x_col  = 'arquivo',
    y_col = 'rotulo',
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 1000 validated image filenames belonging to 2 classes.

# %%
modelo.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=2    
)
# Out:
# Epoch 1/2
# 25/25 [==============================] - 89s 4s/step - loss: 0.0061 - accuracy: 0.9975 - val_loss: 0.0154 - val_accuracy: 0.9948
# Epoch 2/2
# 25/25 [==============================] - 86s 3s/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0313 - val_accuracy: 0.9844

# %%
test_loss,test_accuracy = modelo.evaluate(test_generator, steps = test_generator.samples // test_generator.batch_size)
print(f'Acurácia no teste: (test_accuracy)')
# Out:
# 15/15 [==============================] - 40s 3s/step - loss: 0.0675 - accuracy: 0.9823
# Acurácia no teste: (test_accuracy)

# %%
def preprocessa_imagem(imagem):
    img = image.load_img(imagem, target_size=(224, 224))
    img_tensor = image.img_to_array(img)
    img_tensor = np.expand_dims(img_tensor, axis=0)
    img_tensor /= 255.0
    return img_tensor

# %%
path1 = 'C:/Users/sabri/Desktop/Visao-Computacional/visao_am/'

# %%
img1 = 'C:/Users/sabri//Desktop/Visao-Computacional/visao_am/dc_small/test1/dog.1614.jpg'
img2 = path1 + 'imagens_visao_am/000000002754.jpg'
img3 = path1 + 'imagens_visao_am/gt1.jpg'
img4 = path1 + 'imagens_visao_am/gt2.jpg'

# %%
img1_1 = image.load_img(img1)
plt.imshow(img1_1)

# %%
imagem_tensor = preprocessa_imagem(img1)

# %%
predictions = modelo.predict(imagem_tensor)
resultado_classe = np.argmax(predictions[0])
print('Classe predita: ', resultado_classe)
# Out:
# 1/1 [==============================] - 0s 137ms/step
# Classe predita:  0

# %%
classes = ['cat', 'dog']

# %%
predictions
# Out:
# array([[0.99798054, 0.00201944]], dtype=float32)

# %%
print('Classe predita: ',classes[resultado_classe])
# Out:
# Classe predita:  dog

# %%
img2_2 = image.load_img(img2)
plt.imshow(img2_2)
