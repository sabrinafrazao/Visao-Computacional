# %%
path = 'C:/Users/sabri/Desktop/Visao-Computacional/visao_am/'

# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from keras.applications.efficientnet_v2 import  EfficientNetV2B0, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras.callbacks import TensorBoard
import datetime
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
num_classes = 12

# %%
modelo_base = EfficientNetV2B0(weights='imagenet', include_top=False, input_shape= (224,224,3))

# %%
for layer in modelo_base.layers:
    layer.trainable = False

# %%
modelo = tf.keras.Sequential(
    [modelo_base,
    GlobalAveragePooling2D(),
    Dense(1024, activation='relu'),
    Dense(num_classes, activation = 'softmax')
    ])

# %%
modelo.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                loss = 'categorical_crossentropy',
                metrics = [ 'accuracy'])

# %%
log_dir = 'C:/Users/sabri/Desktop/Visao-Computacional/visao_am/FUND_VC_AM/logsEfficientNet/fit' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq = 1)

# %%
callbacks = [tensorboard_callback]

# %%
path = 'C:/Users/sabri/Desktop/Visao-Computacional/visao_am/FUND_VC_AM/'

# %%
train_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
validation_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)

# %%
train_generator = train_datagen.flow_from_directory(
    directory=os.path.join(path, 'train'),
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 5863 images belonging to 12 classes.

# %%
validation_generator = validation_datagen.flow_from_directory(
    directory=os.path.join(path, 'train'),
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 5863 images belonging to 12 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    directory=os.path.join(path, 'test'),
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 2888 images belonging to 12 classes.

# %%
modelo.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=10,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 91/91 [==============================] - 204s 2s/step - loss: 0.2262 - accuracy: 0.9384 - val_loss: 0.0574 - val_accuracy: 0.9823
# Epoch 2/10
# 91/91 [==============================] - 181s 2s/step - loss: 0.0649 - accuracy: 0.9790 - val_loss: 0.0222 - val_accuracy: 0.9943
# Epoch 3/10
# 91/91 [==============================] - 169s 2s/step - loss: 0.0348 - accuracy: 0.9900 - val_loss: 0.0116 - val_accuracy: 0.9974
# Epoch 4/10
# 91/91 [==============================] - 167s 2s/step - loss: 0.0223 - accuracy: 0.9928 - val_loss: 0.0109 - val_accuracy: 0.9978
# Epoch 5/10
# 91/91 [==============================] - 159s 2s/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0058 - val_accuracy: 0.9991
# Epoch 6/10
# 91/91 [==============================] - 170s 2s/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 0.0053 - val_accuracy: 0.9981
# Epoch 7/10
# 91/91 [==============================] - 174s 2s/step - loss: 0.0145 - accuracy: 0.9943 - val_loss: 0.0059 - val_accuracy: 0.9981
# Epoch 8/10
# 91/91 [==============================] - 176s 2s/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0018 - val_accuracy: 0.9998
# Epoch 9/10
# 91/91 [==============================] - 178s 2s/step - loss: 0.0149 - accuracy: 0.9948 - val_loss: 0.0057 - val_accuracy: 0.9983
# Epoch 10/10
# 91/91 [==============================] - 170s 2s/step - loss: 0.0180 - accuracy: 0.9933 - val_loss: 0.0020 - val_accuracy: 0.9998

# %%
modelo = keras.models.load_model('C:/Users/sabri/Desktop/Visao-Computacional/visao_am/FUND_VC_AM/tl_EfficientNetV2B0_10_epoch.keras')

# %%
test_loss,test_accuracy = modelo.evaluate(test_generator, steps = test_generator.samples // test_generator.batch_size)
print(f'Acurácia no teste: (test_accuracy)')
# Out:
# 45/45 [==============================] - 41s 907ms/step - loss: 18.2861 - accuracy: 0.0344
# Acurácia no teste: (test_accuracy)

# %%
# %load_ext tensorboard

# %%
tensorboard --logdir  'C:/Users/sabri/Desktop/Visao-Computacional/visao_am/FUND_VC_AM/logsEfficientNet/'
# Out:
#       <iframe id="tensorboard-frame-196773d4ef29f2b1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-196773d4ef29f2b1");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
modelo.save(path + 'tl_EfficientNetV2B0_10_epoch.keras')

# %% [markdown]
# Inferência

# %%
def predicao_img(imagem, modelo):
    img = image.load_img(imagem, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    predicoes = modelo.predict(img_array)
    classes =['CarrosPequenos', 'Pessoas_oculos', 'barba', 'bicicletas', 'cabeloEscuro', 'cabelo_claro', 'carro_grande', \
              'helicopteros', 'moto', 'pessoas_capacete', 'pessoas_carecas', 'ruas_alagadas']
    classe_predita = classes[np.argmax(predicoes[0])]
    
    return classe_predita, img

# %%
dir_origem = 'C:/Users/sabri/Desktop/Visao-Computacional/visao_am/FUND_VC_AM/amostras/'

# %%
amostras = [ os.path.join(dir_origem, f) \
           for f in os.listdir(dir_origem) \
           if f.endswith(( '.png', '.jpg', '.jfif', '.jpeg'))]

# %%
for amostra in amostras:
    classe_predita, img = predicao_img(amostra, modelo)
    plt.figure(figsize=(3,3))
    plt.imshow(img)
    plt.title(f'Classe: {classe_predita}')
    plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 87ms/step
