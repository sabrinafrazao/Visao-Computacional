# %%
path = 'C:/Users/IFAM_CMZL/Documents/VC/'

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
modelo = ResNet50(weights='imagenet')
# Out:
# WARNING:tensorflow:From C:\Users\IFAM_CMZL\.conda\envs\visao_am\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\IFAM_CMZL\.conda\envs\visao_am\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# ...
# 102967424/102967424 [==============================] - 26s 0us/step

# %%
img = path + 'imagens_visao_am/tucano3.png'
img = image.load_img(img, target_size=(224, 224))

# %%
img_p = image.img_to_array(img)
img_p = np.expand_dims(img_p, axis=0)
img_p = preprocess_input(img_p)

# %%
preds = modelo.predict(img_p)
# Out:
# 1/1 [==============================] - 1s 814ms/step

# %%
print("Predição: ", decode_predictions(preds, top=5)[0])
# Out:
# ...
# 35363/35363 [==============================] - 0s 3us/step
# Predição:  [('n01843383', 'toucan', 0.92958796), ('n01829413', 'hornbill', 0.054402035), ('n01828970', 'bee_eater', 0.00351861), ('n01820546', 'lorikeet', 0.0030587183), ('n01818515', 'macaw', 0.0013807489)]

# %% [markdown]
# Atividade aula 08

# %% [markdown]
# Modelo DenseNet121

# %%
import tensorflow as tf
from keras.applications.densenet import DenseNet121,preprocess_input, decode_predictions
from keras.applications.efficientnet_v2 import  EfficientNetV2B0, preprocess_input, decode_predictions
from keras.applications.mobilenet import MobileNet, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
modelo1 = DenseNet121(weights='imagenet')

# %%
img1 = path + 'rostos_pessoas_cabelos_escuros/1.jpg'
img1 = image.load_img(img1, target_size=(224, 224))
img2 = path + 'rostos_pessoas_cabelos_escuros/2.jpeg'
img2 = image.load_img(img2, target_size=(224, 224))
img3 = path + 'rostos_pessoas_cabelos_escuros/3.jpg'
img3 = image.load_img(img3, target_size=(224, 224))
img4 = path + 'rostos_pessoas_cabelos_escuros/4.jpg'
img4 = image.load_img(img4, target_size=(224, 224))
img5 = path + 'rostos_pessoas_cabelos_escuros/5.jpg'
img5 = image.load_img(img5, target_size=(224, 224))

# %%
plt.imshow(img1)

# %%
img_p1 = image.img_to_array(img1)
img_p1 = np.expand_dims(img_p1, axis=0)
img_p1 = preprocess_input(img_p1)

# %%
preds = modelo1.predict(img_p1)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03595614', 'jersey', 0.38227218), ('n02837789', 'bikini', 0.09242108), ('n09229709', 'bubble', 0.03269309)]

# %%
plt.imshow(img2)

# %%
img_p2 = image.img_to_array(img2)
img_p2 = np.expand_dims(img_p2, axis=0)
img_p2 = preprocess_input(img_p2)
preds = modelo1.predict(img_p2)
# Out:
# 1/1 [==============================] - 0s 78ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n02667093', 'abaya', 0.18965834), ('n04584207', 'wig', 0.16809128), ('n02837789', 'bikini', 0.08401739)]

# %%
plt.imshow(img3)

# %%
img_p3 = image.img_to_array(img3)
img_p3 = np.expand_dims(img_p3, axis=0)
img_p3 = preprocess_input(img_p3)
preds = modelo1.predict(img_p3)
# Out:
# 1/1 [==============================] - 0s 88ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n04325704', 'stole', 0.19200657), ('n03045698', 'cloak', 0.1340808), ('n02963159', 'cardigan', 0.10858193)]

# %%
plt.imshow(img4)

# %%
img_p4 = image.img_to_array(img4)
img_p4 = np.expand_dims(img_p4, axis=0)
img_p4 = preprocess_input(img_p4)
preds = modelo1.predict(img_p4)
# Out:
# 1/1 [==============================] - 0s 75ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03595614', 'jersey', 0.105674125), ('n03710637', 'maillot', 0.08216558), ('n03450230', 'gown', 0.07527195)]

# %%
plt.imshow(img5)

# %%
img_p5 = image.img_to_array(img5)
img_p5 = np.expand_dims(img_p5, axis=0)
img_p5 = preprocess_input(img_p5)
preds = modelo1.predict(img_p5)
# Out:
# 1/1 [==============================] - 0s 81ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03595614', 'jersey', 0.0872875), ('n04370456', 'sweatshirt', 0.06899414), ('n02963159', 'cardigan', 0.050978307)]

# %% [markdown]
# Modelo  EfficientNetV2B0

# %%
modelo2 = EfficientNetV2B0(weights='imagenet')
# Out:
# ...
# 29403144/29403144 [==============================] - 8s 0us/step

# %%
img1 = path + 'imagens_visao_am/modelo.jpg' 
img1 = image.load_img(img1, target_size=(224, 224))
img2 = path + 'imagens_visao_am/papagaio.jpg'
img2 = image.load_img(img2, target_size=(224, 224))
img3 = path + 'imagens_visao_am/gato1.jpg'
img3 = image.load_img(img3, target_size=(224, 224))
img4 = path + 'imagens_visao_am/onca2.jpg'
img4 = image.load_img(img4, target_size=(224, 224))
img5 = path + 'imagens_visao_am/xadrez.jpg'
img5 = image.load_img(img5, target_size=(224, 224))

# %%
plt.imshow(img1)

# %%
img_p1 = image.img_to_array(img1)
img_p1 = np.expand_dims(img_p1, axis=0)
img_p1 = preprocess_input(img_p1)
preds = modelo2.predict(img_p1)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03729826', 'matchstick', 0.0152462805), ('n01930112', 'nematode', 0.0110275615), ('n03196217', 'digital_clock', 0.009941919)]

# %%
plt.imshow(img2)

# %%
img_p2 = image.img_to_array(img2)
img_p2 = np.expand_dims(img_p2, axis=0)
img_p2 = preprocess_input(img_p2)
preds = modelo2.predict(img_p2)
# Out:
# 1/1 [==============================] - 0s 57ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03729826', 'matchstick', 0.018158887), ('n01930112', 'nematode', 0.012590739), ('n03196217', 'digital_clock', 0.011186495)]

# %%
plt.imshow(img3)

# %%
img_p3 = image.img_to_array(img3)
img_p3 = np.expand_dims(img_p3, axis=0)
img_p3 = preprocess_input(img_p3)
preds = modelo2.predict(img_p3)
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03729826', 'matchstick', 0.017901663), ('n01930112', 'nematode', 0.012591426), ('n03196217', 'digital_clock', 0.011181862)]

# %%
plt.imshow(img4)

# %%
img_p4 = image.img_to_array(img4)
img_p4 = np.expand_dims(img_p4, axis=0)
img_p4 = preprocess_input(img_p4)
preds = modelo2.predict(img_p4)
# Out:
# 1/1 [==============================] - 0s 55ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03729826', 'matchstick', 0.026303563), ('n03196217', 'digital_clock', 0.014819654), ('n01930112', 'nematode', 0.012576361)]

# %%
plt.imshow(img5)

# %%
img_p5 = image.img_to_array(img5)
img_p5 = np.expand_dims(img_p5, axis=0)
img_p5 = preprocess_input(img_p5)
preds = modelo2.predict(img_p5)
# Out:
# 1/1 [==============================] - 0s 44ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03729826', 'matchstick', 0.021863833), ('n01930112', 'nematode', 0.020084875), ('n03196217', 'digital_clock', 0.011474176)]

# %% [markdown]
# Modelo MobileNet

# %%
modelo = MobileNet(weights='imagenet')
# Out:
# ...
# 17225924/17225924 [==============================] - 7s 0us/step

# %%
img1 = path + 'imagens_visao_am/000000002860.jpg' 
img1 = image.load_img(img1, target_size=(224, 224))
img2 = path + 'imagens_visao_am/papagaio.jpg'
img2 = image.load_img(img2, target_size=(224, 224))
img3 = path + 'imagens_visao_am/gato1.jpg'
img3 = image.load_img(img3, target_size=(224, 224))
img4 = path + 'imagens_visao_am/elefante.jpg'
img4 = image.load_img(img4, target_size=(224, 224))
img5 = path + 'imagens_visao_am/t1_tomo.jpg'
img5 = image.load_img(img5, target_size=(224, 224))

# %%
plt.imshow(img1)

# %%
img_p1 = image.img_to_array(img1)
img_p1 = np.expand_dims(img_p1, axis=0)
img_p1 = preprocess_input(img_p1)
preds = modelo.predict(img_p1)
# Out:
# 1/1 [==============================] - 0s 361ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n04285008', 'sports_car', 0.8023008), ('n04037443', 'racer', 0.06310891), ('n02814533', 'beach_wagon', 0.04462562)]

# %%
plt.imshow(img2)

# %%
img_p2 = image.img_to_array(img2)
img_p2 = np.expand_dims(img_p2, axis=0)
img_p2 = preprocess_input(img_p2)
preds = modelo2.predict(img_p2)
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03729826', 'matchstick', 0.018158887), ('n01930112', 'nematode', 0.012590739), ('n03196217', 'digital_clock', 0.011186495)]

# %%
plt.imshow(img3)

# %%
img_p3 = image.img_to_array(img3)
img_p3 = np.expand_dims(img_p3, axis=0)
img_p3 = preprocess_input(img_p3)
preds = modelo2.predict(img_p3)
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03729826', 'matchstick', 0.017901663), ('n01930112', 'nematode', 0.012591426), ('n03196217', 'digital_clock', 0.011181862)]

# %%
plt.imshow(img4)

# %%
img_p4 = image.img_to_array(img4)
img_p4 = np.expand_dims(img_p4, axis=0)
img_p4 = preprocess_input(img_p4)
preds = modelo2.predict(img_p4)
# Out:
# 1/1 [==============================] - 0s 37ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03729826', 'matchstick', 0.02271062), ('n01930112', 'nematode', 0.015369271), ('n03196217', 'digital_clock', 0.01219997)]

# %%
plt.imshow(img5)

# %%
img_p5 = image.img_to_array(img5)
img_p5 = np.expand_dims(img_p5, axis=0)
img_p5 = preprocess_input(img_p5)
preds = modelo2.predict(img_p5)
# Out:
# 1/1 [==============================] - 0s 53ms/step

# %%
print("Predição: ", decode_predictions(preds, top=3)[0])
# Out:
# Predição:  [('n03729826', 'matchstick', 0.023719957), ('n01930112', 'nematode', 0.016668705), ('n03196217', 'digital_clock', 0.013068506)]

# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
num_classes = 2

# %%
modelo_base = ResNet50(weights='imagenet', include_top=False, input_shape= (224,224,3))

# %%
for layer in modelo_base.layers:
    layer.trainable = False

# %%
modelo = tf.keras.Sequential(
    [modelo_base,
    GlobalAveragePooling2D(),
    Dense(1024, activation='relu'),
    Dense(num_classes, activation = 'softmax')
    ])

# %%
modelo.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                loss = 'categorical_crossentropy',
                metrics = [ 'accuracy'])

# %%
path = 'C:/Users\IFAM_CMZL/Documents/VC/dc_small/'

# %%
def criar_dataframe(caminho):
    arquivos = []
    rotulos = []

    for arquivo in os.listdir(caminho):
        if arquivo.startswith('cat'):
            rotulos.append('cat')
        elif arquivo.startswith('dog'):
            rotulos.append('dog')
        arquivos.append(arquivo)
    return pd.DataFrame({'arquivo' : arquivos, 'rotulo': rotulos})

# %%
df_dados = criar_dataframe(os.path.join(path, 'train'))

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   arquivo  2000 non-null   object
#  1   rotulo   2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
df_dados.tail(10)
# Out:
#           arquivo rotulo
# 1990  dog.990.jpg    dog
# 1991  dog.991.jpg    dog
# 1992  dog.992.jpg    dog
# 1993  dog.993.jpg    dog
# 1994  dog.994.jpg    dog
# 1995  dog.995.jpg    dog
# 1996  dog.996.jpg    dog
# 1997  dog.997.jpg    dog
# 1998  dog.998.jpg    dog
# 1999  dog.999.jpg    dog

# %%
train_df, validation_df = train_test_split(df_dados, test_size=0.2, stratify=df_dados['rotulo'])

# %%
test_df = criar_dataframe(os.path.join(path, 'test1'))

# %%
train_df.head()
# Out:
#           arquivo rotulo
# 145   cat.229.jpg    cat
# 1497  dog.546.jpg    dog
# 1852  dog.866.jpg    dog
# 1965  dog.968.jpg    dog
# 215   cat.292.jpg    cat

# %%
validation_df.head()
# Out:
#           arquivo rotulo
# 1900  dog.909.jpg    dog
# 1108  dog.196.jpg    dog
# 412    cat.47.jpg    cat
# 1192  dog.271.jpg    dog
# 1450  dog.503.jpg    dog

# %%
test_df.head()
# Out:
#         arquivo rotulo
# 0  cat.1500.jpg    cat
# 1  cat.1501.jpg    cat
# 2  cat.1502.jpg    cat
# 3  cat.1503.jpg    cat
# 4  cat.1504.jpg    cat

# %%
train_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
validation_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df,
    directory=os.path.join(path, 'train'),
    x_col  = 'arquivo',
    y_col = 'rotulo',
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 1600 validated image filenames belonging to 2 classes.

# %%
validation_generator = validation_datagen.flow_from_dataframe(
    validation_df,
    directory=os.path.join(path, 'train'),
    x_col  = 'arquivo',
    y_col = 'rotulo',
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 400 validated image filenames belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_dataframe(
    test_df,
    directory=os.path.join(path, 'test1'),
    x_col  = 'arquivo',
    y_col = 'rotulo',
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 1000 validated image filenames belonging to 2 classes.

# %%
modelo.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=2    
)
# Out:
# Epoch 1/2
# 25/25 [==============================] - 63s 2s/step - loss: 0.2577 - accuracy: 0.9237 - val_loss: 0.0905 - val_accuracy: 0.9818
# Epoch 2/2
# 25/25 [==============================] - 59s 2s/step - loss: 0.0327 - accuracy: 0.9912 - val_loss: 0.0426 - val_accuracy: 0.9844

# %%
test_loss,test_accuracy = modelo.evaluate(test_generator, steps = test_generator.samples // test_generator.batch_size)
print(f'Acurácia no teste: (test_accuracy)')
# Out:
# 15/15 [==============================] - 29s 2s/step - loss: 0.0640 - accuracy: 0.9833
# Acurácia no teste: (test_accuracy)

# %% [markdown]
# Inferencia do Modelo - Atividade

# %%
path1 = 'C:/Users/IFAM_CMZL/Documents/VC/'

# %%
def preprocessa_imagem(imagem):
    img = image.load_img(imagem, target_size=(224, 224))
    img_tensor = image.img_to_array(img)
    img_tensor = np.expand_dims(img_tensor, axis=0)
    img_tensor /= 255.0
    return img_tensor

# %%
img1 = path + 'imagens_visao_am/000000001915.jpg' 
img2 = path + 'imagens_visao_am/000000002754.jpg'
img3 = path + 'imagens_visao_am/gt1.jpg'
img4 = path + 'imagens_visao_am/gt2.jpg'

# %%
plt.imshow(img2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[407], line 1
# ----> 1 plt.imshow(img2)
#
# File ~\.conda\envs\visao_am\lib\site-packages\matplotlib\pyplot.py:3358, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3337 @_copy_docstring_and_deprecators(Axes.imshow)
#    3338 def imshow(
#    3339     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3356     **kwargs,
#    3357 ) -> AxesImage:
# -> 3358     __ret = gca().imshow(
#    3359         X,
#    3360         cmap=cmap,
#    3361         norm=norm,
#    3362         aspect=aspect,
#    3363         interpolation=interpolation,
#    3364         alpha=alpha,
#    3365         vmin=vmin,
#    3366         vmax=vmax,
#    3367         origin=origin,
#    3368         extent=extent,
# ...

# %%
imagem_tensor = preprocessa_imagem(img1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[408], line 1
# ----> 1 imagem_tensor = preprocessa_imagem(img1)
#
# Cell In[405], line 2, in preprocessa_imagem(imagem)
#       1 def preprocessa_imagem(imagem):
# ----> 2     img = image.load_img(imagem, target_size=(224, 224))
#       3     img_tensor = image.img_to_array(img)
#       4     img_tensor = np.expand_dims(img_tensor, axis=0)
#
# File ~\.conda\envs\visao_am\lib\site-packages\keras\src\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# ...

# %%
plt.imshow(img1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[409], line 1
# ----> 1 plt.imshow(img1)
#
# File ~\.conda\envs\visao_am\lib\site-packages\matplotlib\pyplot.py:3358, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3337 @_copy_docstring_and_deprecators(Axes.imshow)
#    3338 def imshow(
#    3339     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3356     **kwargs,
#    3357 ) -> AxesImage:
# -> 3358     __ret = gca().imshow(
#    3359         X,
#    3360         cmap=cmap,
#    3361         norm=norm,
#    3362         aspect=aspect,
#    3363         interpolation=interpolation,
#    3364         alpha=alpha,
#    3365         vmin=vmin,
#    3366         vmax=vmax,
#    3367         origin=origin,
#    3368         extent=extent,
# ...

# %%
predictions = modelo_base.predict(imagem_tensor)
resultado_classe = np.argmax(predictions[0])
print('Classe predita: ', resultado_classe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[354], line 1
# ----> 1 predictions = modelo_base.predict(imagem_tensor)
#       2 resultado_classe = np.argmax(predictions[0])
#       3 print('Classe predita: ', resultado_classe)
#
# File ~\.conda\envs\visao_am\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File C:\Users\IFAM_C~1\AppData\Local\Temp\__autograph_generated_file9hz5w2py.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
# ...

# %%
classes = [ 'cat',  'dog',]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[336], line 1
# ----> 1 print("Predição: ", decode_predictions(preds, top=3)[0])
#
# File ~\.conda\envs\visao_am\lib\site-packages\keras\src\applications\mobilenet.py:481, in decode_predictions(preds, top)
#     479 @keras_export("keras.applications.mobilenet.decode_predictions")
#     480 def decode_predictions(preds, top=5):
# --> 481     return imagenet_utils.decode_predictions(preds, top=top)
#
# File ~\.conda\envs\visao_am\lib\site-packages\keras\src\applications\imagenet_utils.py:154, in decode_predictions(preds, top)
#     151 global CLASS_INDEX
#     153 if len(preds.shape) != 2 or preds.shape[1] != 1000:
# --> 154     raise ValueError(
#     155         "`decode_predictions` expects "
#     156         "a batch of predictions "
#     157         "(i.e. a 2D array of shape (samples, 1000)). "
# ...
